# %%
import pandas as pd

descriptions = pd.read_csv('dataset/data_descriptions.csv')
train = pd.read_csv('dataset/train.csv')
test = pd.read_csv('dataset/test.csv')

target_col = "Churn"  # change this if your column name is different

# Absolute counts
class_counts = train[target_col].value_counts()
print("Class counts:\n", class_counts)

# Relative proportions
class_ratios = train[target_col].value_counts(normalize=True)
print("\nClass proportions:\n", class_ratios)

# Optional: pretty print
for cls, count in class_counts.items():
    ratio = class_ratios[cls]
    print(f"Class {cls}: {count} samples ({ratio:.2%})")
# Out:
# Class counts:
#  Churn
# 0    199605
# 1     44182
# Name: count, dtype: int64
#
# Class proportions:
#  Churn
# 0    0.818768
# 1    0.181232
# Name: proportion, dtype: float64
# Class 0: 199605 samples (81.88%)
# Class 1: 44182 samples (18.12%)

# %% [markdown]
# our target variable is imbalanced with ~82% non-churners and ~18% churners.

# %% [markdown]
# A dataset is considered imbalanced when:
#
# One class > 70%
#
# Minority class < 30%

# %%
class_counts = test[target_col].value_counts()
print("Class counts:\n", class_counts)

# Relative proportions
class_ratios = test[target_col].value_counts(normalize=True)
print("\nClass proportions:\n", class_ratios)

# Optional: pretty print
for cls, count in class_counts.items():
    ratio = class_ratios[cls]
    print(f"Class {cls}: {count} samples ({ratio:.2%})")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Rakshya\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Churn'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ...
